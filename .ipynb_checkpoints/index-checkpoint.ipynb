# %% [markdown]
# # Football season and impact of the rain on team's performance
# ## 0.0 Imports

# %%
import sqlite3
import pandas as pd
import requests
import json
import numpy as np
import matplotlib.pyplot as plt
import pymongo

# %% [markdown]
# ## 0.1 Goal scored, a function

# %%
def goal_scored(division,season):
    if division not in ['E0','D1','D2']:
        print('The division argument is invalid. It must either be: \n D1 for Bundesliga, \n D2 for Bundesliga 2 \n E0 for Premier League')
    elif season < 1993 or season > 2016:
        print('Sorry, we only have data for seasons between 1993 and 2016!')
    else:
        conn = sqlite3.connect('./database.sqlite')
        cur = conn.cursor()
        query = """
                SELECT Div,HomeTeam, SUM(FTHG)+SUM(FTAG) as Goal_scored 
                FROM Matches 
                WHERE Season = {} 
                GROUP BY HomeTeam 
                ORDER BY Div, Goal_scored desc, HomeTeam""".format(season)
        df = pd.DataFrame(cur.execute(query).fetchall())
        df.columns = [x[0] for x in cur.description]
        g_s = sum(df[df['Div']==division]['Goal_scored'])
        return '{} goals were scored in {} during the {} season!'.format(g_s, division, season)
    
# Add a default counting for all the division and all the season at once

# %%
goal_scored('D1',2011)
# Out:
# '875 goals were scored in D1 during the 2011 season!'

# %% [markdown]
# ## 1. DarkSky API
# ### 1.1 Generate the dataset in need of Weather data

# %%
# Season 2011, everything but a draw
conn = sqlite3.connect('./source/database.sqlite')
cur = conn.cursor()
query = """
        SELECT *,
            CASE FTR 
                WHEN 'A' THEN AwayTeam
                WHEN 'H' THEN HomeTeam
                ELSE Null
            END as 'Winner',
            CASE FTR 
                WHEN 'A' THEN HomeTeam
                WHEN 'H' THEN AwayTeam
                ELSE Null
            END as 'Loser'
        FROM Matches
        WHERE Season = 2011
        """
df = pd.DataFrame(cur.execute(query).fetchall())
df.columns = [x[0] for x in cur.description]
df = df.dropna()
df = df.reset_index()
df['Weather'] = pd.Series(0, index=df.index)
df
# Out:
#      index  Match_ID Div  Season        Date    HomeTeam       AwayTeam  FTHG  \
# 0        0      1092  D1    2011  2012-03-31    Nurnberg  Bayern Munich     0
# 1        1      1093  D1    2011  2011-12-11   Stuttgart  Bayern Munich     1
# 2        2      1094  D1    2011  2011-08-13   Wolfsburg  Bayern Munich     0
# 3        3      1095  D1    2011  2011-11-27       Mainz  Bayern Munich     3
# 4        5      1097  D1    2011  2012-01-20  M'gladbach  Bayern Munich     3
# ..     ...       ...  ..     ...         ...         ...            ...   ...
# 724    987     44870  E0    2011  2012-05-13  Sunderland     Man United     0
# 725    988     44871  E0    2011  2012-05-13     Swansea      Liverpool     1
# 726    989     44872  E0    2011  2012-05-13   Tottenham         Fulham     2
# 727    990     44873  E0    2011  2012-05-13   West Brom        Arsenal     2
# 728    991     44874  E0    2011  2012-05-13       Wigan         Wolves     3
#
#      FTAG FTR         Winner          Loser  Weather
# 0       1   A  Bayern Munich       Nurnberg        0
# 1       2   A  Bayern Munich      Stuttgart        0
# 2       1   A  Bayern Munich      Wolfsburg        0
# 3       2   H          Mainz  Bayern Munich        0
# 4       1   H     M'gladbach  Bayern Munich        0
# ..    ...  ..            ...            ...      ...
# 724     1   A     Man United     Sunderland        0
# 725     0   H        Swansea      Liverpool        0
# 726     0   H      Tottenham         Fulham        0
# 727     3   A        Arsenal      West Brom        0
# 728     2   H          Wigan         Wolves        0
#
# [729 rows x 13 columns]

# %% [markdown]
# ### 1.2 Use the API to populate the weather column

# %%
# Function to get the weather
apikey = dict(json.load(open('/home/antoine/.apikeys')))['Darksky']
def dkSky(division, date):
    lat = None
    long = None
    if division == 'E0':
        lat = 51.528308
        lon = -0.3817815
    else:
        lat = 52.5065133
        lon = 13.1445703
    response = requests.get('https://api.darksky.net/forecast/{}/{},{},{}T16:00:00'.
    format(apikey,lat,lon,date))
    return(response.json()['daily']['data'][0].get('icon', 'Clear'))

# %%
for i in range(0,len(df['Weather'])):
    df['Weather'][i] = dkSky(df['Div'][i],df['Date'][i])
df
# Out:
# <ipython-input-252-e71dd94dd522>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Weather'][i] = dkSky(df['Div'][i],df['Date'][i])
#      index  Match_ID Div  Season        Date    HomeTeam       AwayTeam  FTHG  \
# 0        0      1092  D1    2011  2012-03-31    Nurnberg  Bayern Munich     0
# 1        1      1093  D1    2011  2011-12-11   Stuttgart  Bayern Munich     1
# 2        2      1094  D1    2011  2011-08-13   Wolfsburg  Bayern Munich     0
# 3        3      1095  D1    2011  2011-11-27       Mainz  Bayern Munich     3
# 4        5      1097  D1    2011  2012-01-20  M'gladbach  Bayern Munich     3
# ..     ...       ...  ..     ...         ...         ...            ...   ...
# 724    987     44870  E0    2011  2012-05-13  Sunderland     Man United     0
# 725    988     44871  E0    2011  2012-05-13     Swansea      Liverpool     1
# 726    989     44872  E0    2011  2012-05-13   Tottenham         Fulham     2
# 727    990     44873  E0    2011  2012-05-13   West Brom        Arsenal     2
# 728    991     44874  E0    2011  2012-05-13       Wigan         Wolves     3
#
#      FTAG FTR         Winner          Loser            Weather
# 0       1   A  Bayern Munich       Nurnberg               rain
# 1       2   A  Bayern Munich      Stuttgart  partly-cloudy-day
# 2       1   A  Bayern Munich      Wolfsburg  partly-cloudy-day
# 3       2   H          Mainz  Bayern Munich               wind
# 4       1   H     M'gladbach  Bayern Munich               rain
# ..    ...  ..            ...            ...                ...
# 724     1   A     Man United     Sunderland          clear-day
# 725     0   H        Swansea      Liverpool          clear-day
# 726     0   H      Tottenham         Fulham          clear-day
# 727     3   A        Arsenal      West Brom          clear-day
# 728     2   H          Wigan         Wolves          clear-day
#
# [729 rows x 13 columns]

# %%
set(df['Weather'])
# Out:
# {'Clear', 'clear-day', 'cloudy', 'fog', 'partly-cloudy-day', 'rain', 'wind'}

# %%
# df.to_csv('df.csv', sep=',', encoding='utf-8')

# %%
df = pd.read_csv('df.csv', sep=',', encoding='utf-8')

# %% [markdown]
# ## 2. Wins vs Losses in 2011 season

# %%
# Create the pair Team:Division
conn = sqlite3.connect('./source/database.sqlite')
cur = conn.cursor()
query = """
        SELECT Unique_Teams.TeamName as Teams, Matches.Div as Division
        FROM Unique_Teams
        JOIN Teams_in_Matches ON Unique_Teams.Unique_Team_ID = Teams_in_Matches.Unique_Team_ID
        JOIN Matches ON Teams_in_Matches.Match_ID = Matches.Match_ID
        WHERE Matches.Season = 2011
        GROUP BY Unique_Teams.TeamName
        """
divs = pd.DataFrame(cur.execute(query).fetchall())
divs.columns = [x[0] for x in cur.description]

# %%
# Create the dataframe used to generate the graph
teams = df['Winner'].append(df['Loser'])
uniqueTeams = set(teams)
teamsperf = pd.DataFrame(uniqueTeams)
teamsperf.columns = ['Teams']
teamsperf['Victory'] = [len(df[df['Winner']==team]) for team in uniqueTeams]
teamsperf['Defeat'] = [len(df[df['Loser']==team]) for team in uniqueTeams]
teamsperf = teamsperf.merge(divs, on='Teams')
teamsperf = teamsperf.sort_values(by=['Division', 'Teams'])
teamsperf
# Out:
#                  Teams  Victory  Defeat Division
# 27            Augsburg        8      12       D1
# 16       Bayern Munich       23       7       D1
# 50            Dortmund       25       3       D1
# 52             FC Koln        8      20       D1
# 8             Freiburg       10      14       D1
# 20             Hamburg        8      14       D1
# 54            Hannover       12      10       D1
# 49              Hertha        7      17       D1
# 13          Hoffenheim       10      13       D1
# 12      Kaiserslautern        4      19       D1
# 34          Leverkusen       15      10       D1
# 25          M'gladbach       17       8       D1
# 40               Mainz        9      13       D1
# 29            Nurnberg       12      16       D1
# 51          Schalke 04       20      10       D1
# 0            Stuttgart       15      11       D1
# 39       Werder Bremen       11      14       D1
# 5            Wolfsburg       13      16       D1
# 2               Aachen        6      15       D2
# 43              Bochum       10      17       D2
# 26        Braunschweig       10       9       D2
# 18             Cottbus        8      15       D2
# 55             Dresden       12      13       D2
# 31            Duisburg       10      15       D2
# 11       Ein Frankfurt       20       6       D2
# 35      Erzgebirge Aue        8      15       D2
# 7   Fortuna Dusseldorf       16       4       D2
# 53       Frankfurt FSV        7      13       D2
# 46      Greuther Furth       20       4       D2
# 32       Hansa Rostock        5      17       D2
# 28          Ingolstadt        8      13       D2
# 22           Karlsruhe        9      19       D2
# 48         Munich 1860       17      11       D2
# 30           Paderborn       17       7       D2
# 24            St Pauli       18       8       D2
# 3         Union Berlin       14      14       D2
# 6              Arsenal       21      10       E0
# 37         Aston Villa        7      14       E0
# 9            Blackburn        8      23       E0
# 21              Bolton       10      22       E0
# 23             Chelsea       18      10       E0
# 17             Everton       15      12       E0
# 15              Fulham       14      14       E0
# 44           Liverpool       14      14       E0
# 4             Man City       28       5       E0
# 41          Man United       28       5       E0
# 10           Newcastle       19      11       E0
# 14             Norwich       12      15       E0
# 42                 QPR       10      21       E0
# 45               Stoke       11      15       E0
# 36          Sunderland       11      15       E0
# 47             Swansea       12      15       E0
# 1            Tottenham       20       9       E0
# 38           West Brom       13      17       E0
# 33               Wigan       11      17       E0
# 19              Wolves        5      23       E0

# %%
# Create the graphs, per Division
for i in ['E0','D1','D2']:
    plotdf = teamsperf[teamsperf['Division']==i]
    plotdf.plot(x='Teams', y=['Victory','Defeat'],kind='bar',figsize=(15,10), sort_columns=True,
                title='{}, Season 2011'.format(i))
    plt.savefig('{} - Season 2011'.format(i))

# %% [markdown]
# ## 3. Weather analysis

# %%
teams = df['Winner'].append(df['Loser'])
uniqueTeams = set(teams)
wetperfs = pd.DataFrame(uniqueTeams)
wetperfs.columns = ['Teams']
dfr = df[df['Weather']=='rain']
wetperfs['Victory'] = [len(dfr[dfr['Winner']==team]) for team in uniqueTeams]
wetperfs['Defeat'] = [len(dfr[dfr['Loser']==team]) for team in uniqueTeams]
wetperfs = wetperfs.merge(divs, on='Teams')
wetperfs = wetperfs.sort_values(by=['Division', 'Teams'])
wetperfs
# Out:
#                  Teams  Victory  Defeat Division
# 27            Augsburg        4       4       D1
# 16       Bayern Munich        8       3       D1
# 50            Dortmund        6       2       D1
# 52             FC Koln        4       7       D1
# 8             Freiburg        3       5       D1
# 20             Hamburg        2       5       D1
# 54            Hannover        5       2       D1
# 49              Hertha        3       4       D1
# 13          Hoffenheim        2       4       D1
# 12      Kaiserslautern        0       7       D1
# 34          Leverkusen        6       4       D1
# 25          M'gladbach        8       1       D1
# 40               Mainz        2       4       D1
# 29            Nurnberg        5       4       D1
# 51          Schalke 04        5       4       D1
# 0            Stuttgart        3       3       D1
# 39       Werder Bremen        5       5       D1
# 5            Wolfsburg        4       7       D1
# 2               Aachen        3       1       D2
# 43              Bochum        3       6       D2
# 26        Braunschweig        4       3       D2
# 18             Cottbus        3       4       D2
# 55             Dresden        3       2       D2
# 31            Duisburg        4       7       D2
# 11       Ein Frankfurt        3       2       D2
# 35      Erzgebirge Aue        1       4       D2
# 7   Fortuna Dusseldorf        5       2       D2
# 53       Frankfurt FSV        1       7       D2
# 46      Greuther Furth        8       0       D2
# 32       Hansa Rostock        1       6       D2
# 28          Ingolstadt        2       7       D2
# 22           Karlsruhe        4      11       D2
# 48         Munich 1860       11       6       D2
# 30           Paderborn        6       2       D2
# 24            St Pauli        8       0       D2
# 3         Union Berlin        5       5       D2
# 6              Arsenal        4       2       E0
# 37         Aston Villa        1       5       E0
# 9            Blackburn        3       9       E0
# 21              Bolton        4       7       E0
# 23             Chelsea        6       2       E0
# 17             Everton        6       3       E0
# 15              Fulham        4       3       E0
# 44           Liverpool        6       4       E0
# 4             Man City        7       3       E0
# 41          Man United        6       2       E0
# 10           Newcastle        7       4       E0
# 14             Norwich        3       6       E0
# 42                 QPR        3       5       E0
# 45               Stoke        4       2       E0
# 36          Sunderland        4       5       E0
# 47             Swansea        2       3       E0
# 1            Tottenham        5       4       E0
# 38           West Brom        5       4       E0
# 33               Wigan        3       5       E0
# 19              Wolves        2       7       E0

# %%
an = pd.DataFrame(uniqueTeams)
an.columns = ['Teams']
an['Division'] = teamsperf['Division']
an['Victories'] = teamsperf['Victory']
an['WetVictories'] = wetperfs['Victory']
an['%WetWins'] = np.divide(an['WetVictories'], an['Victories'])
an['%WetWins'] = np.multiply(an['%WetWins'], 100)
an['%WetWins'] = an['%WetWins'].round(decimals=2)
# an = an.sort_values(by=['%WetWins'], ascending=False)
WetWins = {}
for i in ['E0','D1','D2']:
    WetWins[i] = an[an['Division']==i].sort_values(by=['%WetWins'], ascending=False)
    an[an['Division']==i].plot(x='Teams', y=['Victories','WetVictories'],kind='bar',figsize=(15,10),
                title='{}, Wet 2011'.format(i))
    plt.savefig('{} - Wet Season 2011'.format(i))

# %%
WetWins
# Out:
# {'E0':           Teams Division  Victories  WetVictories  %WetWins
#  44    Liverpool       E0         14             6     42.86
#  17      Everton       E0         15             6     40.00
#  19       Wolves       E0          5             2     40.00
#  21       Bolton       E0         10             4     40.00
#  38    West Brom       E0         13             5     38.46
#  9     Blackburn       E0          8             3     37.50
#  10    Newcastle       E0         19             7     36.84
#  45        Stoke       E0         11             4     36.36
#  36   Sunderland       E0         11             4     36.36
#  23      Chelsea       E0         18             6     33.33
#  42          QPR       E0         10             3     30.00
#  15       Fulham       E0         14             4     28.57
#  33        Wigan       E0         11             3     27.27
#  1     Tottenham       E0         20             5     25.00
#  4      Man City       E0         28             7     25.00
#  14      Norwich       E0         12             3     25.00
#  41   Man United       E0         28             6     21.43
#  6       Arsenal       E0         21             4     19.05
#  47      Swansea       E0         12             2     16.67
#  37  Aston Villa       E0          7             1     14.29,
#  'D1':              Teams Division  Victories  WetVictories  %WetWins
#  52         FC Koln       D1          8             4     50.00
#  27        Augsburg       D1          8             4     50.00
#  25      M'gladbach       D1         17             8     47.06
#  39   Werder Bremen       D1         11             5     45.45
#  49          Hertha       D1          7             3     42.86
#  29        Nurnberg       D1         12             5     41.67
#  54        Hannover       D1         12             5     41.67
#  34      Leverkusen       D1         15             6     40.00
#  16   Bayern Munich       D1         23             8     34.78
#  5        Wolfsburg       D1         13             4     30.77
#  8         Freiburg       D1         10             3     30.00
#  20         Hamburg       D1          8             2     25.00
#  51      Schalke 04       D1         20             5     25.00
#  50        Dortmund       D1         25             6     24.00
#  40           Mainz       D1          9             2     22.22
#  13      Hoffenheim       D1         10             2     20.00
#  0        Stuttgart       D1         15             3     20.00
#  12  Kaiserslautern       D1          4             0      0.00,
#  'D2':                  Teams Division  Victories  WetVictories  %WetWins
#  48         Munich 1860       D2         17            11     64.71
#  2               Aachen       D2          6             3     50.00
#  22           Karlsruhe       D2          9             4     44.44
#  24            St Pauli       D2         18             8     44.44
#  46      Greuther Furth       D2         20             8     40.00
#  26        Braunschweig       D2         10             4     40.00
#  31            Duisburg       D2         10             4     40.00
#  18             Cottbus       D2          8             3     37.50
#  3         Union Berlin       D2         14             5     35.71
#  30           Paderborn       D2         17             6     35.29
#  7   Fortuna Dusseldorf       D2         16             5     31.25
#  43              Bochum       D2         10             3     30.00
#  28          Ingolstadt       D2          8             2     25.00
#  55             Dresden       D2         12             3     25.00
#  32       Hansa Rostock       D2          5             1     20.00
#  11       Ein Frankfurt       D2         20             3     15.00
#  53       Frankfurt FSV       D2          7             1     14.29
#  35      Erzgebirge Aue       D2          8             1     12.50}

# %% [markdown]
# ## 4. MongoDB

# %%
myclient = pymongo.MongoClient("mongodb://127.0.0.1:27017/")
mydb = myclient['FootyStats']
mycollection = mydb['TeamNames']
# mycollection.delete_many({})

# %%
# goals = {'goalScored2011D1' : goal_scored('D1',2011),
#             'goalScored2011D2' : goal_scored('D2',2011),
#             'goalScored2011E0' : goal_scored('E0',2011)}
# mycollection.insert_one(goals)

# %%
data = an.to_dict(orient='records')
mycollection.insert_many(data)

# %%
query = mycollection.find({})
for document in query:
    print(document)
# Out:
# {'_id': ObjectId('5e34267c5afaf4eddae57112'), 'goalScored2011D1': '875 goals were scored in D1 during the 2011 season!', 'goalScored2011D2': '855 goals were scored in D2 during the 2011 season!', 'goalScored2011E0': '1066 goals were scored in E0 during the 2011 season!'}
# {'_id': ObjectId('5e343cab5afaf4eddae57116'), 'Teams': 'Stuttgart', 'Division': 'D1', 'Victories': 15, 'WetVictories': 3, '%WetWins': 20.0}
# {'_id': ObjectId('5e343cab5afaf4eddae57117'), 'Teams': 'Tottenham', 'Division': 'E0', 'Victories': 20, 'WetVictories': 5, '%WetWins': 25.0}
# {'_id': ObjectId('5e343cab5afaf4eddae57118'), 'Teams': 'Aachen', 'Division': 'D2', 'Victories': 6, 'WetVictories': 3, '%WetWins': 50.0}
# {'_id': ObjectId('5e343cab5afaf4eddae57119'), 'Teams': 'Union Berlin', 'Division': 'D2', 'Victories': 14, 'WetVictories': 5, '%WetWins': 35.71}
# {'_id': ObjectId('5e343cab5afaf4eddae5711a'), 'Teams': 'Man City', 'Division': 'E0', 'Victories': 28, 'WetVictories': 7, '%WetWins': 25.0}
# {'_id': ObjectId('5e343cab5afaf4eddae5711b'), 'Teams': 'Wolfsburg', 'Division': 'D1', 'Victories': 13, 'WetVictories': 4, '%WetWins': 30.77}
# {'_id': ObjectId('5e343cab5afaf4eddae5711c'), 'Teams': 'Arsenal', 'Division': 'E0', 'Victories': 21, 'WetVictories': 4, '%WetWins': 19.05}
# {'_id': ObjectId('5e343cab5afaf4eddae5711d'), 'Teams': 'Fortuna Dusseldorf', 'Division': 'D2', 'Victories': 16, 'WetVictories': 5, '%WetWins': 31.25}
# {'_id': ObjectId('5e343cab5afaf4eddae5711e'), 'Teams': 'Freiburg', 'Division': 'D1', 'Victories': 10, 'WetVictories': 3, '%WetWins': 30.0}
# {'_id': ObjectId('5e343cab5afaf4eddae5711f'), 'Teams': 'Blackburn', 'Division': 'E0', 'Victories': 8, 'WetVictories': 3, '%WetWins': 37.5}
# {'_id': ObjectId('5e343cab5afaf4eddae57120'), 'Teams': 'Newcastle', 'Division': 'E0', 'Victories': 19, 'WetVictories': 7, '%WetWins': 36.84}
# {'_id': ObjectId('5e343cab5afaf4eddae57121'), 'Teams': 'Ein Frankfurt', 'Division': 'D2', 'Victories': 20, 'WetVictories': 3, '%WetWins': 15.0}
# {'_id': ObjectId('5e343cab5afaf4eddae57122'), 'Teams': 'Kaiserslautern', 'Division': 'D1', 'Victories': 4, 'WetVictories': 0, '%WetWins': 0.0}
# {'_id': ObjectId('5e343cab5afaf4eddae57123'), 'Teams': 'Hoffenheim', 'Division': 'D1', 'Victories': 10, 'WetVictories': 2, '%WetWins': 20.0}
# {'_id': ObjectId('5e343cab5afaf4eddae57124'), 'Teams': 'Norwich', 'Division': 'E0', 'Victories': 12, 'WetVictories': 3, '%WetWins': 25.0}
# {'_id': ObjectId('5e343cab5afaf4eddae57125'), 'Teams': 'Fulham', 'Division': 'E0', 'Victories': 14, 'WetVictories': 4, '%WetWins': 28.57}
# {'_id': ObjectId('5e343cab5afaf4eddae57126'), 'Teams': 'Bayern Munich', 'Division': 'D1', 'Victories': 23, 'WetVictories': 8, '%WetWins': 34.78}
# {'_id': ObjectId('5e343cab5afaf4eddae57127'), 'Teams': 'Everton', 'Division': 'E0', 'Victories': 15, 'WetVictories': 6, '%WetWins': 40.0}
# {'_id': ObjectId('5e343cab5afaf4eddae57128'), 'Teams': 'Cottbus', 'Division': 'D2', 'Victories': 8, 'WetVictories': 3, '%WetWins': 37.5}
# {'_id': ObjectId('5e343cab5afaf4eddae57129'), 'Teams': 'Wolves', 'Division': 'E0', 'Victories': 5, 'WetVictories': 2, '%WetWins': 40.0}
# {'_id': ObjectId('5e343cab5afaf4eddae5712a'), 'Teams': 'Hamburg', 'Division': 'D1', 'Victories': 8, 'WetVictories': 2, '%WetWins': 25.0}
# {'_id': ObjectId('5e343cab5afaf4eddae5712b'), 'Teams': 'Bolton', 'Division': 'E0', 'Victories': 10, 'WetVictories': 4, '%WetWins': 40.0}
# {'_id': ObjectId('5e343cab5afaf4eddae5712c'), 'Teams': 'Karlsruhe', 'Division': 'D2', 'Victories': 9, 'WetVictories': 4, '%WetWins': 44.44}
# {'_id': ObjectId('5e343cab5afaf4eddae5712d'), 'Teams': 'Chelsea', 'Division': 'E0', 'Victories': 18, 'WetVictories': 6, '%WetWins': 33.33}
# {'_id': ObjectId('5e343cab5afaf4eddae5712e'), 'Teams': 'St Pauli', 'Division': 'D2', 'Victories': 18, 'WetVictories': 8, '%WetWins': 44.44}
# {'_id': ObjectId('5e343cab5afaf4eddae5712f'), 'Teams': 'Dresden', 'Division': 'D1', 'Victories': 17, 'WetVictories': 3, '%WetWins': 17.65}
# {'_id': ObjectId('5e343cab5afaf4eddae57130'), 'Teams': "M'gladbach", 'Division': 'D2', 'Victories': 10, 'WetVictories': 8, '%WetWins': 80.0}
# {'_id': ObjectId('5e343cab5afaf4eddae57131'), 'Teams': 'Braunschweig', 'Division': 'D1', 'Victories': 8, 'WetVictories': 4, '%WetWins': 50.0}
# {'_id': ObjectId('5e343cab5afaf4eddae57132'), 'Teams': 'Augsburg', 'Division': 'D2', 'Victories': 8, 'WetVictories': 4, '%WetWins': 50.0}
# {'_id': ObjectId('5e343cab5afaf4eddae57133'), 'Teams': 'Ingolstadt', 'Division': 'D1', 'Victories': 12, 'WetVictories': 2, '%WetWins': 16.67}
# {'_id': ObjectId('5e343cab5afaf4eddae57134'), 'Teams': 'Nurnberg', 'Division': 'D2', 'Victories': 17, 'WetVictories': 5, '%WetWins': 29.41}
# {'_id': ObjectId('5e343cab5afaf4eddae57135'), 'Teams': 'Paderborn', 'Division': 'D2', 'Victories': 10, 'WetVictories': 6, '%WetWins': 60.0}
# {'_id': ObjectId('5e343cab5afaf4eddae57136'), 'Teams': 'Duisburg', 'Division': 'D2', 'Victories': 5, 'WetVictories': 4, '%WetWins': 80.0}
# {'_id': ObjectId('5e343cab5afaf4eddae57137'), 'Teams': 'Hansa Rostock', 'Division': 'E0', 'Victories': 11, 'WetVictories': 1, '%WetWins': 9.09}
# {'_id': ObjectId('5e343cab5afaf4eddae57138'), 'Teams': 'Wigan', 'Division': 'D1', 'Victories': 15, 'WetVictories': 3, '%WetWins': 20.0}
# {'_id': ObjectId('5e343cab5afaf4eddae57139'), 'Teams': 'Leverkusen', 'Division': 'D2', 'Victories': 8, 'WetVictories': 6, '%WetWins': 75.0}
# {'_id': ObjectId('5e343cab5afaf4eddae5713a'), 'Teams': 'Erzgebirge Aue', 'Division': 'E0', 'Victories': 11, 'WetVictories': 1, '%WetWins': 9.09}
# {'_id': ObjectId('5e343cab5afaf4eddae5713b'), 'Teams': 'Sunderland', 'Division': 'E0', 'Victories': 7, 'WetVictories': 4, '%WetWins': 57.14}
# {'_id': ObjectId('5e343cab5afaf4eddae5713c'), 'Teams': 'Aston Villa', 'Division': 'E0', 'Victories': 13, 'WetVictories': 1, '%WetWins': 7.69}
# {'_id': ObjectId('5e343cab5afaf4eddae5713d'), 'Teams': 'West Brom', 'Division': 'D1', 'Victories': 11, 'WetVictories': 5, '%WetWins': 45.45}
# {'_id': ObjectId('5e343cab5afaf4eddae5713e'), 'Teams': 'QPR', 'Division': 'D1', 'Victories': 9, 'WetVictories': 3, '%WetWins': 33.33}
# {'_id': ObjectId('5e343cab5afaf4eddae5713f'), 'Teams': 'Mainz', 'Division': 'E0', 'Victories': 28, 'WetVictories': 2, '%WetWins': 7.14}
# {'_id': ObjectId('5e343cab5afaf4eddae57140'), 'Teams': 'Man United', 'Division': 'E0', 'Victories': 10, 'WetVictories': 6, '%WetWins': 60.0}
# {'_id': ObjectId('5e343cab5afaf4eddae57141'), 'Teams': 'Swansea', 'Division': 'D2', 'Victories': 10, 'WetVictories': 2, '%WetWins': 20.0}
# {'_id': ObjectId('5e343cab5afaf4eddae57142'), 'Teams': 'Bochum', 'Division': 'E0', 'Victories': 14, 'WetVictories': 3, '%WetWins': 21.43}
# {'_id': ObjectId('5e343cab5afaf4eddae57143'), 'Teams': 'Liverpool', 'Division': 'E0', 'Victories': 11, 'WetVictories': 6, '%WetWins': 54.55}
# {'_id': ObjectId('5e343cab5afaf4eddae57144'), 'Teams': 'Stoke', 'Division': 'D2', 'Victories': 20, 'WetVictories': 4, '%WetWins': 20.0}
# {'_id': ObjectId('5e343cab5afaf4eddae57145'), 'Teams': 'Greuther Furth', 'Division': 'E0', 'Victories': 12, 'WetVictories': 8, '%WetWins': 66.67}
# {'_id': ObjectId('5e343cab5afaf4eddae57146'), 'Teams': 'Munich 1860', 'Division': 'D2', 'Victories': 17, 'WetVictories': 11, '%WetWins': 64.71}
# {'_id': ObjectId('5e343cab5afaf4eddae57147'), 'Teams': 'Hertha', 'Division': 'D1', 'Victories': 7, 'WetVictories': 3, '%WetWins': 42.86}
# {'_id': ObjectId('5e343cab5afaf4eddae57148'), 'Teams': 'Dortmund', 'Division': 'D1', 'Victories': 25, 'WetVictories': 6, '%WetWins': 24.0}
# {'_id': ObjectId('5e343cab5afaf4eddae57149'), 'Teams': 'Schalke 04', 'Division': 'D1', 'Victories': 20, 'WetVictories': 5, '%WetWins': 25.0}
# {'_id': ObjectId('5e343cab5afaf4eddae5714a'), 'Teams': 'FC Koln', 'Division': 'D1', 'Victories': 8, 'WetVictories': 4, '%WetWins': 50.0}
# {'_id': ObjectId('5e343cab5afaf4eddae5714b'), 'Teams': 'Frankfurt FSV', 'Division': 'D2', 'Victories': 7, 'WetVictories': 1, '%WetWins': 14.29}
# {'_id': ObjectId('5e343cab5afaf4eddae5714c'), 'Teams': 'Hannover', 'Division': 'D1', 'Victories': 12, 'WetVictories': 5, '%WetWins': 41.67}
# {'_id': ObjectId('5e343cab5afaf4eddae5714d'), 'Teams': 'Werder Bremen', 'Division': 'D2', 'Victories': 12, 'WetVictories': 5, '%WetWins': 41.67}
